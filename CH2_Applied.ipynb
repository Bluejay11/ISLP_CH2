# %%
import pandas as pd
import numpy as np

college = pd.read_csv('/home/jay/repos/Datasets/College.csv')
college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
college2 = pd.read_csv('/home/jay/repos/Datasets/College.csv', index_col = 0)
college2
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college3 = college.rename({'Unnamed: 0': 'College'},axis =1)
college3

# %%
college3 = college3.set_index('College')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_250269/1362220244.py in ?()
# ----> 1 college3 = college3.set_index('College')
#
# ~/.pyenv/versions/3.10.5/lib/python3.10/site-packages/pandas/util/_decorators.py in ?(*args, **kwargs)
#     327                     msg.format(arguments=_format_argument_list(allow_args)),
#     328                     FutureWarning,
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#
# ~/.pyenv/versions/3.10.5/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6008                     if not found:
#    6009                         missing.append(col)
#    6010
#    6011         if missing:
# -> 6012             raise KeyError(f"None of {missing} are in the columns")
#    6013
# ...

# %%
college = college3
college
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
features = ['Top10perc','Apps','Enroll']
pd.plotting.scatter_matrix(college[features]);

# %%
college.boxplot('Outstate', 'Private');

# %%
college['Elite'] = pd.cut(college['Top10perc'], bins=[0,50,100], labels=['no', 'yes'])
college
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college.value_counts(college['Elite'])
# Out:
# Elite
# no     699
# yes     78
# dtype: int64

# %%
college.boxplot('Outstate', 'Elite');

# %%
from matplotlib.pyplot import subplots

fig, axes = plt.subplots(2,2,figsize = (8,8))

fig.tight_layout(pad = 5)

axes[0,0].hist(college['Top10perc'])
axes[0,0].set_title('Top10perc')
axes[0,1].hist(college['Apps'])
axes[0,1].set_title('Apps')
axes[1,0].hist(college['Accept'])
axes[1,0].set_title('Accept')
axes[1,1].hist(college['Enroll'])
axes[1,1].set_title('Enroll');

# %%
Auto = pd.read_csv("/home/jay/repos/Datasets/Auto.csv")
pd.set_option('display.max_rows', 50)
Auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
Auto['horsepower'] = pd.to_numeric(Auto['horsepower'], errors = 'coerce')
Autoq = Auto.select_dtypes(include = 'number')
cols = Autoq.columns.values
np.max(Auto[cols], axis=0)
Auto
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0          4         140.0        86.0    2790          15.6    82
# 393  44.0          4          97.0        52.0    2130          24.6    82
# 394  32.0          4         135.0        84.0    2295          11.6    82
# 395  28.0          4         120.0        79.0    2625          18.6    82
# 396  31.0          4         119.0        82.0    2720          19.4    82
#
#      origin                       name
# ...

# %%
np.min(Auto[cols], axis=0)
# Out:
# mpg                9.0
# cylinders          3.0
# displacement      68.0
# horsepower        46.0
# weight          1613.0
# acceleration       8.0
# year              70.0
# origin             1.0
# dtype: float64

# %%
Auto[cols].describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  397.000000  397.000000    397.000000  392.000000   397.000000
# mean    23.515869    5.458438    193.532746  104.469388  2970.261965
# std      7.825804    1.701577    104.379583   38.491160   847.904119
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.000000   75.000000  2223.000000
# 50%     23.000000    4.000000    146.000000   93.500000  2800.000000
# 75%     29.000000    8.000000    262.000000  126.000000  3609.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration        year      origin
# count    397.000000  397.000000  397.000000
# mean      15.555668   75.994962    1.574307
# std        2.749995    3.690005    0.802549
# min        8.000000   70.000000    1.000000
# 25%       13.800000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
Auto = Auto.drop(np.arange(10,86))
Auto[cols].describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  321.000000  321.000000    321.000000  317.000000   321.000000
# mean    24.444860    5.370717    187.174455  101.003155  2933.183801
# std      7.899928    1.653486     99.864568   36.003208   809.638650
# min     11.000000    3.000000     68.000000   46.000000  1649.000000
# 25%     18.000000    4.000000    100.000000   75.000000  2215.000000
# 50%     23.900000    4.000000    145.000000   90.000000  2795.000000
# 75%     30.700000    6.000000    250.000000  115.000000  3504.000000
# max     46.600000    8.000000    455.000000  230.000000  4997.000000
#
#        acceleration        year      origin
# count    321.000000  321.000000  321.000000
# mean      15.709034   77.143302    1.598131
# std        2.706441    3.128202    0.816163
# min        8.500000   70.000000    1.000000
# 25%       14.000000   75.000000    1.000000
# 50%       15.500000   77.000000    1.000000
# ...

# %%
pd.plotting.scatter_matrix(Auto, figsize = (10,10));

# %%
for x in cols:
    Auto.boxplot(x, 'year');

# %%
for x in cols:
    Auto.boxplot(x, 'origin')

# %%
Boston = pd.read_csv('/home/jay/repos/Datasets/Boston.csv')
pd.set_option('display.max_rows', None)
cols = Boston.columns.values
Boston[Boston.columns.values].describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
Boston
# Out:
#      Unnamed: 0      crim     zn  indus  chas     nox     rm    age      dis  \
# 0             1   0.00632   18.0   2.31     0  0.5380  6.575   65.2   4.0900
# 1             2   0.02731    0.0   7.07     0  0.4690  6.421   78.9   4.9671
# 2             3   0.02729    0.0   7.07     0  0.4690  7.185   61.1   4.9671
# 3             4   0.03237    0.0   2.18     0  0.4580  6.998   45.8   6.0622
# 4             5   0.06905    0.0   2.18     0  0.4580  7.147   54.2   6.0622
# 5             6   0.02985    0.0   2.18     0  0.4580  6.430   58.7   6.0622
# 6             7   0.08829   12.5   7.87     0  0.5240  6.012   66.6   5.5605
# 7             8   0.14455   12.5   7.87     0  0.5240  6.172   96.1   5.9505
# 8             9   0.21124   12.5   7.87     0  0.5240  5.631  100.0   6.0821
# 9            10   0.17004   12.5   7.87     0  0.5240  6.004   85.9   6.5921
# 10           11   0.22489   12.5   7.87     0  0.5240  6.377   94.3   6.3467
# ...

# %%
pd.plotting.scatter_matrix(Boston[cols[1:]], figsize = (12,12));

# %%
for x in cols[1:]:
    Boston.boxplot(x, 'chas')

# %%
Boston.value_counts('chas')
# Out:
# chas
# 0    471
# 1     35
# dtype: int64

# %%
import statistics as st

st.median(Boston['ptratio'])
# Out:
# 19.05

# %%
Boston.sort_values(by = 'medv')
# Out:
#      Unnamed: 0      crim     zn  indus  chas     nox     rm    age      dis  \
# 398         399  38.35180    0.0  18.10     0  0.6930  5.453  100.0   1.4896
# 405         406  67.92080    0.0  18.10     0  0.6930  5.683  100.0   1.4254
# 400         401  25.04610    0.0  18.10     0  0.6930  5.987  100.0   1.5888
# 399         400   9.91655    0.0  18.10     0  0.6930  5.852   77.8   1.5004
# 414         415  45.74610    0.0  18.10     0  0.6930  4.519  100.0   1.6582
# 489         490   0.18337    0.0  27.74     0  0.6090  5.414   98.3   1.7554
# 401         402  14.23620    0.0  18.10     0  0.6930  6.343  100.0   1.5741
# 385         386  16.81180    0.0  18.10     0  0.7000  5.277   98.1   1.4261
# 415         416  18.08460    0.0  18.10     0  0.6790  6.434  100.0   1.8347
# 387         388  22.59710    0.0  18.10     0  0.7000  5.000   89.5   1.5184
# 416         417  10.83420    0.0  18.10     0  0.6790  6.782   90.8   1.8195
# ...

# %%
Boston[cols[1:]].describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %%
count = 0
for x in Boston['rm']:
    if x > 7:
        count = count + 1

count
# Out:
# 64

# %%
Boston8 = Boston['rm'] >=8
Boston7 = Boston['rm'] >=7
Boston.loc[Boston7].describe()
# Out:
#        Unnamed: 0       crim         zn      indus       chas        nox  \
# count   64.000000  64.000000  64.000000  64.000000  64.000000  64.000000
# mean   224.015625   0.979109  28.171875   5.775625   0.125000   0.504455
# std     93.675308   2.807599  34.053089   5.544494   0.333333   0.092863
# min      3.000000   0.009060   0.000000   0.460000   0.000000   0.394000
# 25%    186.000000   0.045023   0.000000   2.460000   0.000000   0.430250
# 50%    230.500000   0.097860  20.000000   3.970000   0.000000   0.488000
# 75%    270.250000   0.542893  45.000000   6.200000   0.000000   0.582500
# max    483.000000  19.609100  95.000000  19.580000   1.000000   0.718000
#
#               rm         age        dis        rad         tax    ptratio  \
# count  64.000000   64.000000  64.000000  64.000000   64.000000  64.000000
# mean    7.570094   60.640625   4.199617   5.984375  312.234375  16.259375
# std     0.481467   27.858587   2.074423   5.655429  118.311365   2.351407
# ...

# %%
Boston.loc[Boston8].describe()
# Out:
#        Unnamed: 0       crim         zn      indus       chas        nox  \
# count   13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean   232.307692   0.718795  13.615385   7.078462   0.153846   0.539238
# std     60.915768   0.901640  26.298094   5.392767   0.375534   0.092352
# min     98.000000   0.020090   0.000000   2.680000   0.000000   0.416100
# 25%    225.000000   0.331470   0.000000   3.970000   0.000000   0.504000
# 50%    233.000000   0.520140   0.000000   6.200000   0.000000   0.507000
# 75%    258.000000   0.578340  20.000000   6.200000   0.000000   0.605000
# max    365.000000   3.474280  95.000000  19.580000   1.000000   0.718000
#
#               rm        age        dis        rad         tax    ptratio  \
# count  13.000000  13.000000  13.000000  13.000000   13.000000  13.000000
# mean    8.348538  71.538462   3.430192   7.461538  325.076923  16.361538
# std     0.251261  24.608723   1.883955   5.332532  110.971063   2.410580
# ...
